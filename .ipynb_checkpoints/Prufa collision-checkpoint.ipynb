# %%
import numpy as np

r = np.random.rand(100,2)

# %%
skoda = np.transpose(r[0,:])
skoda = np.repeat(a=skoda, repeats=[99,99], axis=0)
fjarlaegd = r.dot(skoda)
# Out:
# array([0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
#        0.64502771, 0.64502771, 0.64502771, 0.64502771, 0.64502771,
# ...

# %%
# Out:
# array([[1.03371315],
#        [0.28195126],
#        [0.66156799],
#        [0.64630858],
#        [0.6772361 ],
#        [0.90174389],
#        [0.84391651],
#        [0.49777203],
#        [0.66471944],
#        [0.81882975],
#        [0.90862358],
#        [0.34804664],
#        [0.94987566],
#        [0.50117457],
#        [0.81734826],
#        [0.27989247],
#        [0.28915776],
#        [0.64501767],
#        [0.82002987],
#        [0.87509167],
#        [0.2789632 ],
#        [0.38852161],
#        [0.44921652],
#        [0.59923135],
#        [0.36204526],
#        [0.63113481],
#        [0.80847161],
#        [0.74614724],
#        [0.53511061],
#        [0.52989032],
#        [0.70030219],
#        [0.5593951 ],
#        [0.75100944],
#        [0.89679111],
#        [1.05713775],
#        [0.13445049],
#        [0.58679041],
#        [0.973926  ],
#        [0.44832728],
#        [0.18483023],
#        [0.37604789],
#        [1.12532281],
#        [1.1522796 ],
# ...

# %%
# Out:
# array([[0.97078716],
#        [0.30213481]])
